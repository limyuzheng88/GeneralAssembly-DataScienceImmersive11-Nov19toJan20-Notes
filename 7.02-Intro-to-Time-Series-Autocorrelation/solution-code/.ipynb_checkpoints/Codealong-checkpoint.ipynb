# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Load data
# ---
#
# We'll use [Yahoo! Finance](https://finance.yahoo.com/quote/AAPL) to get a few years worth of stock prices from Apple, Inc. (AAPL)

# %%
# Load data
df = pd.read_csv('../datasets/AAPL.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-12-15  110.699997  111.599998  106.349998  108.230003   99.443619
# 1  2014-12-16  106.370003  110.160004  106.260002  106.750000   98.083740
# 2  2014-12-17  107.120003  109.839996  106.820000  109.410004  100.527809
# 3  2014-12-18  111.870003  112.650002  110.660004  112.650002  103.504761
# 4  2014-12-19  112.260002  113.239998  111.660004  111.779999  102.705391
#
#      Volume
# 0  67218100
# 1  60790700
# 2  53411800
# 3  59006200
# 4  88429800

# %%
# Change date column to be datetime dtype
df['Date'] = pd.to_datetime(df['Date'])
df.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %% [markdown]
# ## Set the `Date` column to be the index
# ---
#
# We'll be exploring a few `pandas` methods related to time series data. In order for them to work we need to set the `Date` column to be the index.

# %%
df.set_index('Date', inplace=True)
df.sort_index(inplace=True)

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-12-15  110.699997  111.599998  106.349998  108.230003   99.443619
# 2014-12-16  106.370003  110.160004  106.260002  106.750000   98.083740
# 2014-12-17  107.120003  109.839996  106.820000  109.410004  100.527809
# 2014-12-18  111.870003  112.650002  110.660004  112.650002  103.504761
# 2014-12-19  112.260002  113.239998  111.660004  111.779999  102.705391
#
#               Volume
# Date
# 2014-12-15  67218100
# 2014-12-16  60790700
# 2014-12-17  53411800
# 2014-12-18  59006200
# 2014-12-19  88429800

# %% [markdown]
# ## Explore the data
# ---
#
# - `Close`: The price of AAPL when the stock market closes (at 4:30pm ET)
# - `Adj Close`: The closing price, when accounting for dividend payments, stock splits, etc.
# - `High`: The highest price of AAPL during that trading day
# - `Low`: The lowest price of AAPL during that trading day
# - `Open`: The price of AAPL when the stock market opens (at 9:30am ET)
# - `Volume`: How many shares of AAPL were traded that day

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-07-28  149.889999  150.229996  149.190002  149.500000  145.004379
# 2017-07-31  149.899994  150.330002  148.130005  148.729996  144.257507
# 2017-08-01  149.100006  150.220001  148.410004  150.050003  145.537842
# 2017-08-02  159.279999  159.750000  156.160004  157.139999  152.414627
# 2017-08-03  157.050003  157.210007  155.020004  155.570007  150.891830
#
#               Volume
# Date
# 2017-07-28  17213700
# 2017-07-31  19845900
# 2017-08-01  35368600
# 2017-08-02  69936800
# 2017-08-03  27097300

# %% [markdown]
# ## Filtering by dates
# ---
#
# Now that our `Date` column is the index, we can filter our data in unique ways. Try `df['2018']` in the cell below:

# %%
df['2018'] #having done to_datetime earlier, the code can understand this
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-02  170.160004  172.300003  169.259995  172.259995  167.199890
# 2018-01-03  172.529999  174.550003  171.960007  172.229996  167.170776
# 2018-01-04  172.539993  173.470001  172.080002  173.029999  167.947266
# 2018-01-05  173.440002  175.369995  173.050003  175.000000  169.859406
# 2018-01-08  174.350006  175.610001  173.929993  174.350006  169.228500
# ...                ...         ...         ...         ...         ...
# 2018-12-24  148.149994  151.550003  146.589996  146.830002  144.656540
# 2018-12-26  148.300003  157.229996  146.720001  157.169998  154.843475
# 2018-12-27  155.839996  156.770004  150.070007  156.149994  153.838562
# 2018-12-28  157.500000  158.520004  154.550003  156.229996  153.917389
# 2018-12-31  158.529999  159.360001  156.479996  157.740005  155.405045
#
#               Volume
# Date
# 2018-01-02  25555900
# 2018-01-03  29517900
# 2018-01-04  22434600
# 2018-01-05  23660000
# 2018-01-08  20567800
# ...              ...
# 2018-12-24  37169200
# 2018-12-26  58582500
# 2018-12-27  53117100
# 2018-12-28  42291400
# 2018-12-31  35003500
#
# [251 rows x 6 columns]

# %% [markdown]
# You can also filter by month:

# %%
df['2019-03']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-03-01  174.279999  175.149994  172.889999  174.970001  173.119278
# 2019-03-04  175.690002  177.750000  173.970001  175.850006  173.989990
# 2019-03-05  175.940002  176.000000  174.539993  175.529999  173.673370
# 2019-03-06  174.669998  175.490005  173.940002  174.520004  172.674057
# 2019-03-07  173.869995  174.440002  172.020004  172.500000  170.675415
# 2019-03-08  170.320007  173.070007  169.500000  172.910004  171.081085
# 2019-03-11  175.490005  179.119995  175.350006  178.899994  177.007706
# 2019-03-12  180.000000  182.669998  179.369995  180.910004  178.996475
# 2019-03-13  182.250000  183.300003  180.919998  181.710007  179.787994
# 2019-03-14  183.899994  184.100006  182.559998  183.729996  181.786621
# 2019-03-15  184.850006  187.330002  183.740005  186.119995  184.151337
# 2019-03-18  185.800003  188.389999  185.789993  188.020004  186.031265
# 2019-03-19  188.350006  188.990005  185.919998  186.529999  184.557022
# 2019-03-20  186.229996  189.490005  184.729996  188.160004  186.169785
# 2019-03-21  190.020004  196.330002  189.809998  195.089996  193.026459
# 2019-03-22  195.339996  197.690002  190.779999  191.050003  189.029205
# 2019-03-25  191.509995  191.979996  186.600006  188.740005  186.743637
# 2019-03-26  191.660004  192.880005  184.580002  186.789993  184.814255
# 2019-03-27  188.750000  189.759995  186.550003  188.470001  186.476486
# 2019-03-28  188.949997  189.559998  187.529999  188.720001  186.723846
# 2019-03-29  189.830002  190.080002  188.539993  189.949997  187.940842
#
#               Volume
# Date
# 2019-03-01  25886200
# 2019-03-04  27436200
# 2019-03-05  19737400
# 2019-03-06  20810400
# 2019-03-07  24796400
# 2019-03-08  23999400
# 2019-03-11  32011000
# 2019-03-12  32467600
# 2019-03-13  31032500
# 2019-03-14  23579500
# 2019-03-15  39042900
# 2019-03-18  26219800
# 2019-03-19  31646400
# 2019-03-20  31035200
# 2019-03-21  51034200
# 2019-03-22  42407700
# 2019-03-25  43845300
# 2019-03-26  49800500
# 2019-03-27  29848400
# 2019-03-28  20780400
# 2019-03-29  23564000

# %% [markdown]
# ## Resampling
# ---
#
# `df.resample()` is similar to `df.groupby()`, but with dates instead of categories.

# %%
df.resample('M').mean()  # finding mean for each mth
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-07-31  149.894996  150.279999  148.660004  149.114998  144.630943
# 2017-08-31  158.946958  160.151740  157.803479  159.021306  154.663035
# 2017-09-30  158.109000  158.869501  156.446500  157.608500  153.469347
# 2017-10-31  157.355907  158.586818  156.670456  157.817273  153.672636
# 2017-11-30  172.490476  173.428095  170.990952  172.406191  168.280443
# 2017-12-31  171.721999  172.885499  170.848501  171.891500  167.978944
# 2018-01-31  174.021428  175.203334  172.818096  174.005237  170.044569
# 2018-02-28  167.276316  169.887893  165.479475  167.638947  164.289279
# 2018-03-31  175.047143  176.799524  173.061430  174.496192  171.219596
# 2018-04-30  169.765238  171.657618  168.292382  169.834287  166.645232
# 2018-05-31  184.956365  186.469091  183.862273  185.536818  182.504684
# 2018-06-30  188.720477  189.831906  187.419047  188.621429  185.793280
# 2018-07-31  190.196190  191.540000  189.014760  190.311429  187.457947
# 2018-08-31  212.486957  214.561304  211.305652  213.346089  210.666574
# 2018-09-30  222.331053  224.530526  220.077895  222.073685  219.511128
# 2018-10-31  221.200001  223.940871  217.874347  220.845652  218.297262
# 2018-11-30  191.819523  193.949523  188.700475  191.235714  189.516928
# 2018-12-31  165.243158  167.320001  161.891054  164.266317  162.937348
# 2019-01-31  153.608571  155.530478  151.947619  154.166190  152.918935
# 2019-02-28  171.392108  172.881580  170.531579  171.727893  170.877196
# 2019-03-31  183.223810  184.931906  181.410952  183.293810  182.590657
# 2019-04-30  199.866665  201.577143  198.630951  200.516191  199.746969
# 2019-05-31  190.938636  193.369544  189.205001  191.273637  191.021427
# 2019-06-30  192.664498  194.796001  191.233001  192.969000  192.969000
# 2019-07-31  204.078947  205.572631  203.108420  204.382107  204.382107
#
#                   Volume
# Date
# 2017-07-31  1.852980e+07
# 2017-08-31  2.874213e+07
# 2017-09-30  3.401870e+07
# 2017-10-31  2.292233e+07
# 2017-11-30  2.860302e+07
# 2017-12-31  2.655919e+07
# 2018-01-31  3.141330e+07
# 2018-02-28  4.883654e+07
# 2018-03-31  3.398703e+07
# 2018-04-30  3.172163e+07
# 2018-05-31  2.822620e+07
# 2018-06-30  2.512498e+07
# 2018-07-31  1.874721e+07
# 2018-08-31  3.044865e+07
# 2018-09-30  3.573537e+07
# 2018-10-31  3.433689e+07
# 2018-11-30  4.577745e+07
# 2018-12-31  4.731171e+07
# 2019-01-31  3.943273e+07
# 2019-02-28  2.487056e+07
# 2019-03-31  3.099911e+07
# 2019-04-30  2.410084e+07
# 2019-05-31  3.361166e+07
# 2019-06-30  2.576094e+07
# 2019-07-31  1.837099e+07

# %%
df['2019-04'].mean()
# Out:
# Open         1.998667e+02
# High         2.015771e+02
# Low          1.986310e+02
# Close        2.005162e+02
# Adj Close    1.983953e+02
# Volume       2.410084e+07
# dtype: float64

# %% [markdown]
# ## Lookup challenge
# ---
#
# Where can you find all the resample options?

# %% [markdown]
# ### A:
# With cursor on function, press shift-tab

# %% [markdown]
# ## "Rolling" Functions
# ---
#
# With time series, we can "roll" statistics across time. For example, the rolling mean is the mean of a moving window across time periods. Pandas offers a variety of functionalities for creating rolling statistics, which we'll only scratch the surface of here.
#
# The syntax for these can be a little tricky at first. We'll be using a `rolling()` function with a statistical function chained to it. Let's dive into more detail.

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-12-15  110.699997  111.599998  106.349998  108.230003   99.443619
# 2014-12-16  106.370003  110.160004  106.260002  106.750000   98.083740
# 2014-12-17  107.120003  109.839996  106.820000  109.410004  100.527809
# 2014-12-18  111.870003  112.650002  110.660004  112.650002  103.504761
# 2014-12-19  112.260002  113.239998  111.660004  111.779999  102.705391
#
#               Volume
# Date
# 2014-12-15  67218100
# 2014-12-16  60790700
# 2014-12-17  53411800
# 2014-12-18  59006200
# 2014-12-19  88429800

# %%
df.rolling(2).mean().head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-12-15         NaN         NaN         NaN         NaN         NaN
# 2014-12-16  108.535000  110.880001  106.305000  107.490002   98.763679
# 2014-12-17  106.745003  110.000000  106.540001  108.080002   99.305774
# 2014-12-18  109.495003  111.244999  108.740002  111.030003  102.016285
# 2014-12-19  112.065002  112.945000  111.160004  112.215001  103.105076
#
#                 Volume
# Date
# 2014-12-15         NaN
# 2014-12-16  64004400.0
# 2014-12-17  57101250.0
# 2014-12-18  56209000.0
# 2014-12-19  73718000.0

# %% [markdown]
# ## Challenge
# ---
#
# Concatenate the `Close` column with the 3 day rolling mean of the `Close` column.

# %%
pd.concat([
    df[['Close']],
    df[['Close']].rolling(3).mean().rename(columns={'Close': 'Close 3 Day Avg'})
], axis=1).head()
# Out:
#                  Close  Close 3 Day Avg
# Date
# 2014-12-15  108.230003              NaN
# 2014-12-16  106.750000              NaN
# 2014-12-17  109.410004       108.130002
# 2014-12-18  112.650002       109.603335
# 2014-12-19  111.779999       111.280002

# %% [markdown]
# ## Challenge
# ---
#
# Plot a line chart with two lines:
# 1. The `Open` price
# 2. The 30 day rolling mean of the `Open` price

# %%
plt.figure(figsize=(12,9))
plt.plot(df['Open']);
plt.plot(df['Open'].rolling(30).mean());
plt.legend(labels=('Open','Open (rolling30)'));

# %% [markdown]
# ## `.diff()`
# ---
# The `.diff()` calculates the difference in a value between a value at time $T$ and that same value at $T-1$. For example, if I have a dataframe of stock prices:
#
# <table style="float: left;">
#   <thead>
#     <tr>
#       <th></th>
#       <th>Close</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1-1-2019</th>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>1-2-2019</th>
#       <td>110</td>
#     </tr>
#   </tbody>
# </table>
#
# <div style="clear: both;"></div>
#
# When I call `.diff()`, I get the following:
# <table style="float: left;">
#   <thead>
#     <tr>
#       <th></th>
#       <th>Close</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1-1-2019</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1-2-2019</th>
#       <td>10</td>
#     </tr>
#   </tbody>
# </table>
# <div style="clear: both;"></div>

# %%
df.diff().head()
# Out:
#                 Open      High       Low     Close  Adj Close      Volume
# Date
# 2014-12-15       NaN       NaN       NaN       NaN        NaN         NaN
# 2014-12-16 -4.329994 -1.439994 -0.089996 -1.480003  -1.359879  -6427400.0
# 2014-12-17  0.750000 -0.320008  0.559998  2.660004   2.444069  -7378900.0
# 2014-12-18  4.750000  2.810006  3.840004  3.239998   2.976952   5594400.0
# 2014-12-19  0.389999  0.589996  1.000000 -0.870003  -0.799370  29423600.0

# %% [markdown]
# ## `.pct_change()`
# ---
#
# `.pct_change()` works similar to `.diff()`, except we're calculating the difference as a change in percentage: $X_{t}/X_{t-1} - 1$
#
# So if I have my table of stock prices:
#
# <table style="float: left;">
#   <thead>
#     <tr>
#       <th></th>
#       <th>Close</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1-1-2019</th>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>1-2-2019</th>
#       <td>110</td>
#     </tr>
#   </tbody>
# </table>
#
# <div style="clear: both;"></div>
#
# The `.pct_change()` will look like this:
#
# <table style="float: left;">
#   <thead>
#     <tr>
#       <th></th>
#       <th>Close</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1-1-2019</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1-2-2019</th>
#       <td>.1</td>
#     </tr>
#   </tbody>
# </table>
#
# <div style="clear: both;"></div>
#
#
# We'd interpret 1-2-2019 as a 10% increase (110/100 - 1 = .10) in price from the day before. Again, the first row is a `NaN` since there is no prior row to calcuate the percent change from.

# %%
df.pct_change().head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2014-12-15       NaN       NaN       NaN       NaN        NaN       NaN
# 2014-12-16 -0.039115 -0.012903 -0.000846 -0.013675  -0.013675 -0.095620
# 2014-12-17  0.007051 -0.002905  0.005270  0.024918   0.024918 -0.121382
# 2014-12-18  0.044343  0.025583  0.035948  0.029613   0.029613  0.104741
# 2014-12-19  0.003486  0.005237  0.009037 -0.007723  -0.007723  0.498653

# %% [markdown]
# ## Challenge
# ---
#
# Create three **separate** plots:
# 1. One for the `Close` price
# 2. One for the `Close` price, using `.diff()`
# 3. One for the `Close` price as a percent change.
#
# What happens to your overall data when you diff? Is this good or bad?

# %%
fig, axes = plt.subplots(nrows=3, figsize=(12,9))
axes[0].plot(df.Close)
axes[1].plot(df.Close.diff())
axes[2].plot(df.Close.pct_change())

# %% [markdown]
# We now see that the general trend, the statistical properties (eg. mean) has become somewhat constant. Hence for this dataset, only 1 round of differencing is required.

# %% [markdown]
# ## Volatility
# ---
#
# The volatility for AAPL can be thought of as the standard deviation of the returns (`.pct_change()`). We can use the `.rolling()` method to see how AAPL's volatility changes over time.
#
# In the cell below, plot the 10 day rolling standard deviation of APPL's returns for `Close` (**THAT'S A MOUTHFUL!**)

# %%
plt.figure(figsize=(12,6))
df.Close.pct_change().rolling(10).std().plot()

# %% [markdown]
# ## Shifting
# ---
#
# `df.shift()` is used to bring values from previous dates forward in time.

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-12-15  110.699997  111.599998  106.349998  108.230003   99.443619
# 2014-12-16  106.370003  110.160004  106.260002  106.750000   98.083740
# 2014-12-17  107.120003  109.839996  106.820000  109.410004  100.527809
# 2014-12-18  111.870003  112.650002  110.660004  112.650002  103.504761
# 2014-12-19  112.260002  113.239998  111.660004  111.779999  102.705391
#
#               Volume
# Date
# 2014-12-15  67218100
# 2014-12-16  60790700
# 2014-12-17  53411800
# 2014-12-18  59006200
# 2014-12-19  88429800

# %%
df.shift().head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-12-15         NaN         NaN         NaN         NaN         NaN
# 2014-12-16  110.699997  111.599998  106.349998  108.230003   99.443619
# 2014-12-17  106.370003  110.160004  106.260002  106.750000   98.083740
# 2014-12-18  107.120003  109.839996  106.820000  109.410004  100.527809
# 2014-12-19  111.870003  112.650002  110.660004  112.650002  103.504761
#
#                 Volume
# Date
# 2014-12-15         NaN
# 2014-12-16  67218100.0
# 2014-12-17  60790700.0
# 2014-12-18  53411800.0
# 2014-12-19  59006200.0

# %% [markdown]
# ## Creating a simple dataset
# ---
#
# Let's create a simple dataset that tries to predict today's `Close` price using yesterday's `Close` price with today's `Open` price.

# %%
pd.concat([
    df[['Close']].rename(columns={'Close': 'y'}),
    df[['Close']].shift().rename(columns={'Close': 'prev_close'}),
    df[['Open']].rename(columns={'Open': 'open'})
], axis=1).head()
# Out:
#                      y  prev_close        open
# Date
# 2014-12-15  108.230003         NaN  110.699997
# 2014-12-16  106.750000  108.230003  106.370003
# 2014-12-17  109.410004  106.750000  107.120003
# 2014-12-18  112.650002  109.410004  111.870003
# 2014-12-19  111.779999  112.650002  112.260002
